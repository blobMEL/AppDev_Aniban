# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Collab_ICT107/Python_WorkSheet_3
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Collab_ICT107/Python_WorkSheet_4'
# /content

# %% [markdown]
# # CHAPTER 10 - Tuples

# %% [markdown]
# ##EXERCISE-1

# %% [markdown]
# Create a tuple with the following items: `1, 1, 2, 3, 5`. Feed the tuple to the `sum()` built-in function and check the result.

# %% [markdown]
# ###ANSWER:

# %%
num = (1,1,2,3,5)
sum(num)
# Out:
# 12

# %% [markdown]
# ##EXERCISE-2

# %% [markdown]
# Unpack the following tuple into meaningful variables and display them
#
# ```python
# ph_info = ('Philippines', 'Manila', 103.3) # The last number is the Population in Millions as of 2016
# ```

# %% [markdown]
# ###ANSWER:

# %%
ph_info = ('Philippines', 'Manila', 103.3)
# The last number is the Population in Millions as of 2016
country, town, population_in_mil = ph_info
print(f"The last number is the Population of {country}, {town} in Million as of 2016: {population_in_mil}")
# Out:
# The last number is the Population of Philippines, Manila in Million as of 2016: 103.3
