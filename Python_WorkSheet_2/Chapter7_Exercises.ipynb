# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Collab_ICT107/Python_Worksheet_2
# Out:
# /content/drive/MyDrive/Collab_ICT107/Python_Worksheet_2

# %%
# !touch chap7_exercise_worksheet2.py

# %%
# !touch words.txt

# %%
f = open('words.txt', 'w')
f.write('Mel Christian Aniban\nbscs\n2-b')
f.close()

# %% [markdown]
# # CHAPTER  7 - Files

# %% [markdown]
# ##EXERCISE-1

# %% [markdown]
# `Write a program to read through a file and print the contents of the file (line by line) all in upper case.`
#
# from [PEW] E8-1

# %% [markdown]
# ###Answer:

# %%
read = open('words.txt', 'r')
count = 0
for line in read:
    upper_texts =line.upper()
    print(upper_texts)
# Out:
# MEL CHRISTIAN ANIBAN
#
# BSCS
#
# 2-B

# %% [markdown]
# ##EXERCISE-2

# %% [markdown]
# `Write a program to read through a file and output the number of lines in a file.`
#
# adapted from [PEW]

# %% [markdown]
# ###Answer:

# %%
read = open('words.txt', 'r')
count = 0
for line in read:
    count = count + 1
print(count)
# Out:
# 3

# %% [markdown]
# ##CHALLENGE

# %% [markdown]
# Write a program to prompt for a file name, and then read through the file and look for lines of the form:

# %% [markdown]
# ```
# X-DSPAM-Confidence: 0.8475
# ```

# %% [markdown]
# When you encounter a line that starts with "X-DSPAM-Confidence:" pull apart the line to extract the floating-point number on the line. Count these lines and then compute the total of the spam confidence values from these lines. When you reach the end of the file, print out the average spam confidence.

# %% [markdown]
# ```
# Enter the file name: mbox.txt
# Average spam confidence: 0.894128046745
#
# Enter the file name: mbox-short.txt
# Average spam confidence: 0.750718518519
# ```

# %% [markdown]
# ###Answer:

# %%
file = input("Enter the file name: ")

try:
    read_file = open( file , 'r')
    sum_spam_cofidence = 0
    count = 0

    for line in read_file:
        if line.startswith('X-DSPAM-Confidence:'):
          line = line.rstrip()
          count= count + 1
          spam_cofidence = float(line[-5:])
          sum_spam_cofidence = sum_spam_cofidence + spam_cofidence

    ave_spam_cofidence = sum_spam_cofidence/count

    print("Average spam confidence: {:.12f}".format(ave_spam_cofidence))

except:
    print(file + ' does not exist.')
# Out:
# Enter the file name: mbox.txt
# Average spam confidence: 0.894128046745
