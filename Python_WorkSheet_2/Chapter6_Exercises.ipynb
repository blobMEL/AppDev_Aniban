# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Collab_ICT107/Python_Worksheet_2
# Out:
# /content/drive/MyDrive/Collab_ICT107/Python_Worksheet_2

# %%
# !touch chap1_exercise_worksheet2.py

# %% [markdown]
# # CHAPTER 6  - `Strings`

# %% [markdown]
# ##EXERCISE-1

# %% [markdown]
# Given the code below
#
#     text = 'Business Analytics'
#
# What will the following expressions produce?
#
#     text[4]
#     text[2:4]
#     text[:4]
#     text[4:]
#     text[-2]
#     text[-4:-2]
#     text[-2:]
#     text[:-2]

# %% [markdown]
# ###Answer:

# %% [markdown]
#     1. text[4]
#        -> s
#
#     2. text[2:4]
#        -> si
#
#     3. text[:4]
#        -> Busi
#
#     4. text[4:]
#        -> ness Analytics
#
#     5. text[-2]
#        -> c
#
#     5. text[-4:-2]
#        -> ti
#
#     6. text[-2:]
#       -> cs
#
#     7. text[:-2]
#       ->Business Analyti

# %% [markdown]
# ##EXERCISE-2

# %% [markdown]
# Given the code below:
#
#     phrase = 'One Ring to rule them all'
#
# What string slicing expression gives out the following words:
#
#     'One '
#     'Ring'
#     'all'
#     'them'
#     'One Ring to rule them all'

# %% [markdown]
# ###Answer:

# %%
phrase = 'One Ring to rule them all'

print(phrase[:4])
print(phrase[4:8])
print(phrase[-3:])
print(phrase[-8:-5])
print(phrase[:])
# Out:
# One
# Ring
# all
# the
# One Ring to rule them all

# %% [markdown]
# ##CHALLENGE

# %% [markdown]
# Write a program which repeatedly reads a **full name**, then does the following:
# - strips the name of any trailing spaces
# - capitalizes the first letter
# - puts the rest into smaller letters

# %%
while (True):
  name = input("Enter Name: ")
  name_strip = name.replace(" ", "")
  name_strip = name_strip.capitalize()
  print(name_strip)
  if (name == ""):
    break
# Out:
# Enter Name: Mel Aniban
# Melaniban
# Enter Name: JOHN REY ORTIGAS
# Johnreyortigas
# Enter Name: eLSA mAgsael
# Elsamagsael
# Enter Name: Kenneth joHn      lopez
# Kennethjohnlopez
# Enter Name: cathy                MUEGa
# Cathymuega
# Enter Name:
