# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Collab_ICT107/
# Out:
# /content/drive/MyDrive/Collab_ICT107

# %%
# !touch chap5_exercises.py

# %% [markdown]
# #CHAPTER-5

# %% [markdown]
# ##EXERCISE-1

# %% [markdown]
# Investigate on the difference between `is` and `==` given the following variables.
# ```python
# a = 2
# b = 2.0
# c = a
# ```

# %% [markdown]
# ###EXPLAINATION:

# %% [markdown]
# The `==` compares two variable values if they are equal while the `is` compares a variable(x) to another variable(y) if that variable(y) is the variable itself(x).

# %% [markdown]
# ##CHALLENGE-1

# %% [markdown]
# Write a program which repeatedly reads numbers until the user enters "done". Once "done" is entered, print out the total, count, and average of the numbers. If the user enters anything other than a number, detect their mistake using try and except and print an error message and skip to the next number.
#
#     Enter a number: 4
#     Enter a number: 5
#     Enter a number: bad data
#     Invalid input
#     Enter a number: 7
#     Enter a number: done
#     16 3 5.333333333333333
#
# [PEW] E5.1

# %% [markdown]
# ###PROGRAM CODE:

# %%
n = 0
total = 0
while True:
  n_str = input('Enter a number:')
  try:
      n_int = int(n_str)
      total += n_int
      n+=1
      ave = total/n
  except:
      if n_str == 'done':
        print(total, n, ave)
        break
      print("Invalid input")
# Out:
# Enter a number:4
# Enter a number:5
# Enter a number:bad data
# Invalid input
# Enter a number:7
# Enter a number:done
# 16 3 5.333333333333333

# %% [markdown]
# ##CHALLENGE-2

# %% [markdown]
# Write another program that prompts for a list of numbers as above and at the end prints out both the maximum and minimum of the numbers instead of the average.

# %% [markdown]
# ###PROGRAM CODE:

# %%
min = float()
max = float()

while True:
  n_str = input('Enter a number: ')
  if n_str == 'done':
    if max == 0 and min == 0:
      print("No number is Entered!!!")
      break
    else:
      print(max, min)
      break
  try:
      n_int = float(n_str)
      if n_int < min or min == 0:
        min = n_int
      if n_int > max:
        max = n_int
  except:
      print("Invalid input")
# Out:
# Enter a number: 9
# Enter a number: 2
# Enter a number: 3
# Enter a number: 6
# Enter a number: 2
# Enter a number: 1
# Enter a number: 8
# Enter a number: done
# 9.0 1.0
