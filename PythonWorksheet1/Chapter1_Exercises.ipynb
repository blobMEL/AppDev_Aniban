# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/Collab_ICT107/Python_WorkSheet_1
# Out:
# /content/drive/MyDrive/Collab_ICT107/Python_WorkSheet_1

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Collab_ICT107/Python_WorkSheet_1

# %%
# !dir

# %%
# !touch chap_exercise.py

# %% [markdown]
# #Chapter 1 - Introduction

# %% [markdown]
# #EXERCISE-1

# %% [markdown]
# ##First Code:

# %% [markdown]
# Each line of code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
Print('Hello world!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-5780b2d87702> in <cell line: 1>()
# ----> 1 Print('Hello world!')
#
# NameError: name 'Print' is not defined

# %% [markdown]
# Answer & Explaination:

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# In the previous code the "Print('Hello world')" has a function name error because Python doesn't allow its function to have a capital letter in the beginning of the function.

# %% [markdown]
# The 'P' of the "Print('Hello world')" shoud be not be capitalized.

# %% [markdown]
# ##Second Code:

# %%
print'Hello world!')
# Out:
#   File "<ipython-input-25-027e3a63a2c5>", line 1
#     print'Hello world!')
#                        ^
# SyntaxError: unmatched ')'

# %% [markdown]
# Answer & Explaination:

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# The code error function is missing an open parenthersis.

# %% [markdown]
# ##Third Code:

# %%
print('Hello world!)
# Out:
#   File "<ipython-input-23-66f32fd1004b>", line 1
#     print('Hello world!)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# Answer & Explaination:

# %%
print('Hello world!')

# %% [markdown]
# The error code is missing a qoutation.

# %% [markdown]
# ##Fourth Code:

# %%
print('Hello world!'')
# Out:
#   File "<ipython-input-24-7fd42fd5a36c>", line 1
#     print('Hello world!'')
#                         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# Answer & Explaination:

# %%
print('Hello world!')

# %% [markdown]
# The error code has too many qoutation.

# %% [markdown]
# #EXERCISE-2

# %% [markdown]
# ##FIRST CODE:

# %%
x = 43
x = x + 1
print(x)

# %% [markdown]
# ANSWER & EXPLAINATION:

# %% [markdown]
# The output would be 44 because first the x is initialized as 43, and then the x is initialized as x (which is equivalent to 43) + 1, so the value of the x would then be 44.

# %% [markdown]
# #EXERCISE-3

# %% [markdown]
# ##FIRST CODE:

# %%
x = 43
x = X + 1
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e86e654f3854> in <cell line: 2>()
#       1 x = 43
# ----> 2 x = X + 1
#       3 print(x)
#
# NameError: name 'X' is not defined

# %% [markdown]
# ANSWER & EXPLAINANTION:

# %%
x = 43
x = x + 1
print(x)

# %% [markdown]
# The error code used 'X' which is not stated or defined and 'X' is different than the 'x'.
