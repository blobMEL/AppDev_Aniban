# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/Collab_ICT107/Python_WorkSheet_1
# Out:
# /content/drive/MyDrive/Collab_ICT107/Python_WorkSheet_1

# %%
# !touch chap2_exercises.py

# %% [markdown]
# # CHAPTER 2 - Variables, Expressions, and Statements

# %% [markdown]
# ##EXERCISE-1

# %% [markdown]
# Write a program that uses input to prompt a user for their name and then welcomes them.
# ~~~
# Enter your name: Chuck
# Hello Chuck
# ~~~

# %% [markdown]
# ###PROGRAM:

# %%
x = input("Enter name: ")
print("Hello",x)
# Out:
# Enter name:MEL
# Hello MEL

# %% [markdown]
# ##EXERCISE-2

# %% [markdown]
# Write a program to prompt the user for hours and rate per hour to compute gross pay.
# ```
# Enter Hours: 35
# Enter Rate: 2.75
# Pay: 96.25
# ```

# %% [markdown]
# ###PROGRAM:

# %%
hour = float(input("Enter Hours: "))
rate = float(input("Enter Rate: "))
pay = print("Pay: ", hour*rate)
# Out:
# Enter Hours: 35
# Enter Rate: 2.75
# Pay:  96.25

# %% [markdown]
# ##EXERCISE-3

# %% [markdown]
# Assume that we execute the following assignment statements:
# ```python
# width = 17
# height = 12.0
# ```
# For each of the following expressions, write the value of the expression and the type (of the value of the expression).
# ```python
# width//2
# width/2.0
# height/3
# 1 + 2 * 5
# ```

# %% [markdown]
# ###PROGRAM:

# %%
width = 17
height = 12.0
ex1 = width/2
ex2 = width/2.0
ex3 = height/3
ex4 = 1 + 2 * 5

print(type(ex1), ex1)
print(type(ex2), ex2)
print(type(ex3), ex3)
print(type(ex4), ex4)
# Out:
# <class 'float'> 8.5
# <class 'float'> 8.5
# <class 'float'> 4.0
# <class 'int'> 11

# %% [markdown]
# ##EXERCISE-4

# %% [markdown]
# #### Exercise 4
#
# Write a program that uses input to prompt a user for a number and then outputs the square of the number
# ```
# Enter a number: 3
# The square of 3 is 9
# ```

# %% [markdown]
# ###PROGRAM:

# %%
x = int(input("Enter a number: "))
print("The square of", x , "is", x*x)
# Out:
# Enter a number: 3
# The square of 3 is 9

# %% [markdown]
# ##CHALLENGE

# %% [markdown]
# Write a program which prompts the user for a Celsius temperature, convert the temperature to Fahrenheit, and print out the converted temperature.

# %% [markdown]
# ###PROGRAM:

# %%
cel = float(input("Enter Temperature in Celsius: "))
fah = ((cel*9)/5) + 32

print("Celsius =", cel,"°C","To Fahrenheit = ", fah)
# Out:
# Enter Temperature in Celsius: 5
# Celsius = 5.0 °C To Fahrenheit =  41.0
